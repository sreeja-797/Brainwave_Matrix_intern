# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
credit_card_data = pd.read_csv('/content/creditcard.csv (1).zip')

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
legit=credit_card_data[credit_card_data.Class ==0]
fraud=credit_card_data[credit_card_data.Class ==1]

# %%
print(legit.shape)
# Out:
# (284315, 31)

# %%
print(fraud.shape)
# Out:
# (492, 31)

# %%
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
legit_sample=legit.sample(n=492)

# %%
new_dataset=pd.concat([legit_sample,fraud], axis=0)

# %%
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 173599  121555.0 -0.760042  0.322992 -0.349159 -1.862656 -0.118993 -0.363447
# 217858  141070.0  1.934770 -0.172355 -1.021018  1.307668 -0.186544 -0.612912
# 269347  163633.0  1.989534 -0.275265 -0.290746  0.337681 -0.704980 -0.765747
# 251017  155172.0  1.585535 -2.414810 -0.431139 -1.140868 -2.250362 -0.954308
# 224275  143720.0  1.757259 -0.023838  0.944493  3.773188 -0.820666  0.855771
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 173599  0.330708 -1.080998 -1.095172  ...  1.279180  1.429766 -0.077038
# 217858 -0.105167 -0.006872  0.582040  ...  0.359613  1.128991 -0.051421
# 269347 -0.474230 -0.065023  1.362727  ... -0.115750 -0.197915  0.363615
# 251017 -0.907407 -0.312360 -1.188847  ... -0.075022 -0.491343  0.191759
# 224275 -1.165241  0.483432 -0.100729  ...  0.281617  0.811455  0.275421
#
# ...

# %%
new_dataset.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94219.292683 -0.025296  0.081250 -0.122170 -0.035068 -0.116554
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0     -0.029394 -0.003515  0.053482 -0.016274  ... -0.042653  0.037660
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.020301 -0.015014  0.004666 -0.015771  0.013652  0.006817  0.003133
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       85.208577
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
X=new_dataset.drop(columns='Class',axis =1)
Y=new_dataset['Class']

# %%
print(X)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 173599  121555.0 -0.760042  0.322992 -0.349159 -1.862656 -0.118993 -0.363447
# 217858  141070.0  1.934770 -0.172355 -1.021018  1.307668 -0.186544 -0.612912
# 269347  163633.0  1.989534 -0.275265 -0.290746  0.337681 -0.704980 -0.765747
# 251017  155172.0  1.585535 -2.414810 -0.431139 -1.140868 -2.250362 -0.954308
# 224275  143720.0  1.757259 -0.023838  0.944493  3.773188 -0.820666  0.855771
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
print(Y)
# Out:
# 173599    0
# 217858    0
# 269347    0
# 251017    0
# 224275    0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %%
X_train,X_test,Y_train,y_test=train_test_split(X,Y,test_size=0.2,stratify=Y,random_state=2)

# %%
 print(X.shape,X_train.shape,X_test.shape)
# Out:
# (984, 30) (787, 30) (197, 30)

# %%
model=LogisticRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction , Y_train)

# %%
print(training_data_accuracy)
# Out:
# 0.9479034307496823

# %%
X_test_prediction =model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction,y_test)

# %%
print(test_data_accuracy)
# Out:
# 0.9543147208121827

# %%
import numpy as np

# Sample input with 30 features: [Time, V1, ..., V28, Amount]
fraud_like_transaction = np.array([[0.0, -1.3598, -0.0728, 2.5363, 1.3781, -0.3383, 0.4624, 0.2396,
                                    0.0987, 0.3637, 0.0908, -0.5516, -0.6178, -0.9914, -0.3112,
                                    1.4681, -0.4704, 0.2070, 0.0258, 0.4039, 0.2514, -0.0183,
                                    0.2778, -0.1105, -0.2862, 0.0074, 0.0000, 0.0000, 0.0, 149.62]])

# Reshape input to (1, 30)
fraud_like_transaction = fraud_like_transaction.reshape(1, -1)

# Scale it if needed
# fraud_like_transaction = scaler.transform(fraud_like_transaction)

# Predict
prediction = model.predict(fraud_like_transaction)

# Output
if prediction[0] == 0:
    print("✅ Legit Transaction")
else:
    print("❌ Fraudulent Transaction")
# Out:
# ✅ Legit Transaction
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
print(model.feature_names_in_)
# Out:
# ['Time' 'V1' 'V2' 'V3' 'V4' 'V5' 'V6' 'V7' 'V8' 'V9' 'V10' 'V11' 'V12'
#  'V13' 'V14' 'V15' 'V16' 'V17' 'V18' 'V19' 'V20' 'V21' 'V22' 'V23' 'V24'
#  'V25' 'V26' 'V27' 'V28' 'Amount']

# %%
import numpy as np
import pandas as pd

# Create sample fraud-like transaction with all 30 features
fraud_like_transaction = np.array([[0.0,      # Time
                                    -2.3122,   # V1
                                    1.9512,    # V2
                                    -1.6098,   # V3
                                    3.9979,    # V4
                                    -0.5225,   # V5
                                    -3.4262,   # V6
                                    -0.6755,   # V7
                                    2.3638,    # V8
                                    0.3762,    # V9
                                    0.5421,    # V10
                                    -2.7702,   # V11
                                    -0.3275,   # V12
                                    1.9607,    # V13
                                    -4.4012,   # V14
                                    -1.1012,   # V15
                                    0.3300,    # V16
                                    -0.1054,   # V17
                                    -0.1247,   # V18
                                    -0.0362,   # V19
                                    0.1335,    # V20
                                    -0.0210,   # V21
                                    0.0212,    # V22
                                    -0.1623,   # V23
                                    0.0628,    # V24
                                    0.0615,    # V25
                                    -0.0734,   # V26
                                    0.0010,    # V27
                                    -0.0598,   # V28
                                    212.0]])   # Amount ($212 transaction)

# Reshape to 1 sample x 30 features
fraud_like_transaction = fraud_like_transaction.reshape(1, -1)
column_names = ['Time'] + [f'V{i}' for i in range(1, 29)] + ['Amount']
fraud_like_df = pd.DataFrame(fraud_like_transaction, columns=column_names)

# Use this if your model was trained on a DataFrame with feature names
prediction = model.predict(fraud_like_df)
if prediction[0] == 0:
    print("✅ Legit Transaction")
else:
    print("❌ Fraudulent Transaction")
# Out:
# ❌ Fraudulent Transaction
